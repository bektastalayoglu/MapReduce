# %%
import numpy as np  # Fundamental package for numerical computing
import pandas as pd  # Library for data manipulation and analysis

# %%
file_path = 'Iris.csv'  # Adjust the path if necessary
data = pd.read_csv(file_path)

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            6.2           2.2            4.5           1.5
# 1      2            5.0           3.5            1.3           0.3
# 2      3            6.3           3.3            4.7           1.6
# 3      4            6.1           2.9            4.7           1.4
# 4      5            7.2           3.0            5.8           1.6
# ..   ...            ...           ...            ...           ...
# 145  146            5.7           4.4            1.5           0.4
# 146  147            4.8           3.1            1.6           0.2
# 147  148            5.7           2.8            4.1           1.3
# 148  149            7.7           2.8            6.7           2.0
# 149  150            6.7           3.1            5.6           2.4
#
#              Species
# 0    Iris-versicolor
# 1        Iris-setosa
# 2    Iris-versicolor
# 3    Iris-versicolor
# 4     Iris-virginica
# ..               ...
# 145      Iris-setosa
# 146      Iris-setosa
# 147  Iris-versicolor
# 148   Iris-virginica
# 149   Iris-virginica
#
# [150 rows x 6 columns]

# %%
features = data.columns[1:-1]  # Feature columns (exclude the last one)

# %%
features
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'], dtype='object')

# %%
x = data.loc[:, features].values

# %%
x
# Out:
# array([[6.2, 2.2, 4.5, 1.5],
#        [5. , 3.5, 1.3, 0.3],
#        [6.3, 3.3, 4.7, 1.6],
#        [6.1, 2.9, 4.7, 1.4],
#        [7.2, 3. , 5.8, 1.6],
#        [6.7, 3. , 5. , 1.7],
#        [6.2, 2.8, 4.8, 1.8],
#        [4.4, 3.2, 1.3, 0.2],
#        [5.8, 2.7, 4.1, 1. ],
#        [5.1, 3.8, 1.5, 0.3],
#        [4.4, 3. , 1.3, 0.2],
#        [6.2, 2.9, 4.3, 1.3],
#        [5.6, 3. , 4.5, 1.5],
#        [6.3, 2.9, 5.6, 1.8],
#        [4.8, 3.4, 1.6, 0.2],
#        [6.5, 3. , 5.5, 1.8],
#        [6.7, 3.3, 5.7, 2.5],
#        [6. , 2.9, 4.5, 1.5],
#        [7.2, 3.6, 6.1, 2.5],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.8, 2.7, 5.1, 1.9],
#        [4.9, 2.4, 3.3, 1. ],
#        [5.9, 3. , 4.2, 1.5],
#        [6.4, 2.9, 4.3, 1.3],
#        [6.8, 3. , 5.5, 2.1],
#        [5.5, 2.3, 4. , 1.3],
#        [5.2, 4.1, 1.5, 0.1],
#        [4.6, 3.1, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.6, 3.6, 1. , 0.2],
#        [4.6, 3.2, 1.4, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [5.9, 3.2, 4.8, 1.8],
#        [5.8, 2.8, 5.1, 2.4],
#        [6.7, 3. , 5.2, 2.3],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.5, 3. , 5.2, 2. ],
#        [7. , 3.2, 4.7, 1.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [5.7, 2.9, 4.2, 1.3],
#        [7.6, 3. , 6.6, 2.1],
#        [5. , 3.5, 1.6, 0.6],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.4, 1.7, 0.2],
#        [4.6, 3.4, 1.4, 0.3],
#        [5.4, 3.9, 1.7, 0.4],
#        [6.1, 2.8, 4. , 1.3],
#        [6. , 3. , 4.8, 1.8],
#        [4.8, 3. , 1.4, 0.1],
#        [6.3, 2.5, 5. , 1.9],
#        [5.6, 2.8, 4.9, 2. ],
#        [6.9, 3.2, 5.7, 2.3],
#        [6.3, 3.3, 6. , 2.5],
#        [6.7, 3.1, 4.4, 1.4],
#        [5.7, 3. , 4.2, 1.2],
#        [6.8, 2.8, 4.8, 1.4],
#        [7.9, 3.8, 6.4, 2. ],
#        [6.3, 2.7, 4.9, 1.8],
#        [5.6, 2.5, 3.9, 1.1],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.8, 4. , 1.2, 0.2],
#        [6.4, 3.2, 5.3, 2.3],
#        [5.3, 3.7, 1.5, 0.2],
#        [6. , 2.2, 5. , 1.5],
#        [5.4, 3.4, 1.5, 0.4],
#        [6.2, 3.4, 5.4, 2.3],
#        [4.9, 3. , 1.4, 0.2],
#        [5.4, 3. , 4.5, 1.5],
#        [4.8, 3. , 1.4, 0.3],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.4, 3.1, 5.5, 1.8],
#        [6.1, 2.8, 4.7, 1.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [6.5, 3.2, 5.1, 2. ],
#        [4.9, 3.1, 1.5, 0.1],
#        [6.5, 3. , 5.8, 2.2],
#        [6.8, 3.2, 5.9, 2.3],
#        [4.9, 2.5, 4.5, 1.7],
#        [4.7, 3.2, 1.3, 0.2],
#        [5.6, 3. , 4.1, 1.3],
#        [5.1, 3.4, 1.5, 0.2],
#        [6.4, 2.8, 5.6, 2.2],
#        [7.7, 3.8, 6.7, 2.2],
#        [5. , 3.2, 1.2, 0.2],
#        [7.2, 3.2, 6. , 1.8],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.2, 3.5, 1.5, 0.2],
#        [6.1, 2.6, 5.6, 1.4],
#        [5.5, 2.5, 4. , 1.3],
#        [5.5, 3.5, 1.3, 0.2],
#        [6.7, 3.1, 4.7, 1.5],
#        [6.6, 2.9, 4.6, 1.3],
#        [6.7, 3.3, 5.7, 2.1],
#        [6.3, 3.4, 5.6, 2.4],
#        [5.1, 3.5, 1.4, 0.2],
#        [5.1, 3.8, 1.6, 0.2],
#        [6.9, 3.1, 5.1, 2.3],
#        [5. , 3.3, 1.4, 0.2],
#        [4.3, 3. , 1.1, 0.1],
#        [7.1, 3. , 5.9, 2.1],
#        [5.5, 2.4, 3.7, 1. ],
#        [5.7, 2.5, 5. , 2. ],
#        [5.6, 2.9, 3.6, 1.3],
#        [5.1, 3.8, 1.9, 0.4],
#        [4.8, 3.4, 1.9, 0.2],
#        [6.4, 2.8, 5.6, 2.1],
#        [6.4, 2.7, 5.3, 1.9],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.9, 3. , 5.1, 1.8],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.8, 2.7, 3.9, 1.2],
#        [5.5, 2.4, 3.8, 1.1],
#        [5. , 2. , 3.5, 1. ],
#        [5.5, 4.2, 1.4, 0.2],
#        [5.8, 2.7, 5.1, 1.9],
#        [5. , 3.4, 1.5, 0.2],
#        [5.1, 2.5, 3. , 1.1],
#        [6. , 2.2, 4. , 1. ],
#        [5.8, 2.6, 4. , 1.2],
#        [6.3, 2.5, 4.9, 1.5],
#        [5.4, 3.7, 1.5, 0.2],
#        [6. , 2.7, 5.1, 1.6],
#        [6.9, 3.1, 5.4, 2.1],
#        [5. , 3. , 1.6, 0.2],
#        [5.7, 2.6, 3.5, 1. ],
#        [6.1, 3. , 4.6, 1.4],
#        [5.7, 2.8, 4.5, 1.3],
#        [6. , 3.4, 4.5, 1.6],
#        [6.3, 2.3, 4.4, 1.3],
#        [5.2, 3.4, 1.4, 0.2],
#        [7.7, 3. , 6.1, 2.3],
#        [6.5, 2.8, 4.6, 1.5],
#        [5.2, 2.7, 3.9, 1.4],
#        [6.6, 3. , 4.4, 1.4],
#        [4.5, 2.3, 1.3, 0.3],
#        [7.7, 2.6, 6.9, 2.3],
#        [5. , 2.3, 3.3, 1. ],
#        [5.5, 2.6, 4.4, 1.2],
#        [7.4, 2.8, 6.1, 1.9],
#        [4.7, 3.2, 1.6, 0.2],
#        [6.1, 3. , 4.9, 1.8],
#        [5.4, 3.9, 1.3, 0.4],
#        [5. , 3.4, 1.6, 0.4],
#        [6.7, 2.5, 5.8, 1.8],
#        [5.7, 4.4, 1.5, 0.4],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.7, 2.8, 4.1, 1.3],
#        [7.7, 2.8, 6.7, 2. ],
#        [6.7, 3.1, 5.6, 2.4]])

# %%
min_vals = x.min(axis=0)  # Min of each feature
max_vals = x.max(axis=0)  # Max of each feature
x_normalized = (x - min_vals) / (max_vals - min_vals)

# %%
x_normalized_df = pd.DataFrame(x_normalized, columns=features)

# %%
# Add back the 'Id' column and the label/species column
x_normalized_df.insert(0, 'Id', data['Id'])  # Insert 'Id' as the first column
x_normalized_df['Species'] = data['Species']  # Add 'Species' column

# %%
x_normalized_df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1       0.527778      0.083333       0.593220      0.583333
# 1      2       0.194444      0.625000       0.050847      0.083333
# 2      3       0.555556      0.541667       0.627119      0.625000
# 3      4       0.500000      0.375000       0.627119      0.541667
# 4      5       0.805556      0.416667       0.813559      0.625000
# ..   ...            ...           ...            ...           ...
# 145  146       0.388889      1.000000       0.084746      0.125000
# 146  147       0.138889      0.458333       0.101695      0.041667
# 147  148       0.388889      0.333333       0.525424      0.500000
# 148  149       0.944444      0.333333       0.966102      0.791667
# 149  150       0.666667      0.458333       0.779661      0.958333
#
#              Species
# 0    Iris-versicolor
# 1        Iris-setosa
# 2    Iris-versicolor
# 3    Iris-versicolor
# 4     Iris-virginica
# ..               ...
# 145      Iris-setosa
# 146      Iris-setosa
# 147  Iris-versicolor
# 148   Iris-virginica
# 149   Iris-virginica
#
# [150 rows x 6 columns]
