# %%
import numpy as np  # Fundamental package for numerical computing
import pandas as pd  # Library for data manipulation and analysis
from sklearn.preprocessing import MinMaxScaler

# %%
file_path = 'Iris.csv'  # Adjust the path if necessary
data = pd.read_csv(file_path)
features = data.columns[1:-1]  # Feature columns (exclude the last one)
x = data.loc[:, features].values
min_vals = x.min(axis=0)  # Min of each feature
max_vals = x.max(axis=0)  # Max of each feature
x_normalized = (x - min_vals) / (max_vals - min_vals)
x_normalized_df = pd.DataFrame(x_normalized, columns=features)

# Add back the 'Id' column and the label/species column
x_normalized_df.insert(0, 'Id', data['Id'])  # Insert 'Id' as the first column
x_normalized_df['Species'] = data['Species']  # Add 'Species' column

# Separate known and unknown sample IDs and features
KNOWN_SAMPLES = x_normalized_df.dropna(subset=['Species']).to_dict(orient='records')  # Known samples
UNKNOWN_SAMPLES = x_normalized_df[x_normalized_df['Species'].isna()].to_dict(orient='records')  # Unknown samples

# %%
KNOWN_SAMPLES
# Out:
# [{'Id': 1,
#   'SepalLengthCm': 0.5277777777777778,
#   'SepalWidthCm': 0.0833333333333334,
#   'PetalLengthCm': 0.5932203389830508,
#   'PetalWidthCm': 0.5833333333333334,
#   'Species': 'Iris-versicolor'},
#  {'Id': 2,
#   'SepalLengthCm': 0.19444444444444448,
#   'SepalWidthCm': 0.6249999999999999,
#   'PetalLengthCm': 0.05084745762711865,
#   'PetalWidthCm': 0.08333333333333333,
#   'Species': 'Iris-setosa'},
#  {'Id': 3,
#   'SepalLengthCm': 0.5555555555555555,
#   'SepalWidthCm': 0.5416666666666665,
#   'PetalLengthCm': 0.6271186440677966,
#   'PetalWidthCm': 0.625,
#   'Species': 'Iris-versicolor'},
#  {'Id': 4,
#   'SepalLengthCm': 0.4999999999999999,
#   'SepalWidthCm': 0.3749999999999999,
#   'PetalLengthCm': 0.6271186440677966,
#   'PetalWidthCm': 0.5416666666666666,
#   'Species': 'Iris-versicolor'},
#  {'Id': 5,
#   'SepalLengthCm': 0.8055555555555556,
#   'SepalWidthCm': 0.41666666666666663,
#   'PetalLengthCm': 0.8135593220338982,
#   'PetalWidthCm': 0.625,
#   'Species': 'Iris-virginica'},
#  {'Id': 6,
#   'SepalLengthCm': 0.6666666666666666,
#   'SepalWidthCm': 0.41666666666666663,
#   'PetalLengthCm': 0.6779661016949152,
#   'PetalWidthCm': 0.6666666666666666,
#   'Species': 'Iris-versicolor'},
#  {'Id': 7,
#   'SepalLengthCm': 0.5277777777777778,
#   'SepalWidthCm': 0.3333333333333332,
#   'PetalLengthCm': 0.6440677966101694,
#   'PetalWidthCm': 0.7083333333333334,
#   'Species': 'Iris-virginica'},
#  {'Id': 8,
#   'SepalLengthCm': 0.027777777777777922,
#   'SepalWidthCm': 0.5,
#   'PetalLengthCm': 0.05084745762711865,
#   'PetalWidthCm': 0.04166666666666667,
#   'Species': 'Iris-setosa'},
#  {'Id': 9,
#   'SepalLengthCm': 0.41666666666666663,
#   'SepalWidthCm': 0.2916666666666667,
#   'PetalLengthCm': 0.5254237288135593,
#   'PetalWidthCm': 0.375,
#   'Species': 'Iris-versicolor'},
#  {'Id': 10,
#   'SepalLengthCm': 0.22222222222222213,
#   'SepalWidthCm': 0.7499999999999998,
#   'PetalLengthCm': 0.0847457627118644,
#   'PetalWidthCm': 0.08333333333333333,
#   'Species': 'Iris-setosa'},
#  {'Id': 11,
#   'SepalLengthCm': 0.027777777777777922,
#   'SepalWidthCm': 0.41666666666666663,
#   'PetalLengthCm': 0.05084745762711865,
#   'PetalWidthCm': 0.04166666666666667,
#   'Species': 'Iris-setosa'},
#  {'Id': 12,
#   'SepalLengthCm': 0.5277777777777778,
#   'SepalWidthCm': 0.3749999999999999,
#   'PetalLengthCm': 0.559322033898305,
#   'PetalWidthCm': 0.5,
#   'Species': 'Iris-versicolor'},
#  {'Id': 13,
#   'SepalLengthCm': 0.361111111111111,
#   'SepalWidthCm': 0.41666666666666663,
#   'PetalLengthCm': 0.5932203389830508,
#   'PetalWidthCm': 0.5833333333333334,
#   'Species': 'Iris-versicolor'},
#  {'Id': 14,
#   'SepalLengthCm': 0.5555555555555555,
#   'SepalWidthCm': 0.3749999999999999,
#   'PetalLengthCm': 0.7796610169491525,
#   'PetalWidthCm': 0.7083333333333334,
#   'Species': 'Iris-virginica'},
#  {'Id': 15,
#   'SepalLengthCm': 0.13888888888888887,
#   'SepalWidthCm': 0.5833333333333333,
#   'PetalLengthCm': 0.1016949152542373,
#   'PetalWidthCm': 0.04166666666666667,
#   'Species': 'Iris-setosa'},
#  {'Id': 16,
#   'SepalLengthCm': 0.611111111111111,
#   'SepalWidthCm': 0.41666666666666663,
#   'PetalLengthCm': 0.7627118644067796,
#   'PetalWidthCm': 0.7083333333333334,
#   'Species': 'Iris-virginica'},
#  {'Id': 17,
#   'SepalLengthCm': 0.6666666666666666,
#   'SepalWidthCm': 0.5416666666666665,
#   'PetalLengthCm': 0.7966101694915254,
#   'PetalWidthCm': 1.0,
#   'Species': 'Iris-virginica'},
#  {'Id': 18,
#   'SepalLengthCm': 0.4722222222222222,
#   'SepalWidthCm': 0.3749999999999999,
#   'PetalLengthCm': 0.5932203389830508,
#   'PetalWidthCm': 0.5833333333333334,
#   'Species': 'Iris-versicolor'},
#  {'Id': 19,
#   'SepalLengthCm': 0.8055555555555556,
#   'SepalWidthCm': 0.6666666666666666,
#   'PetalLengthCm': 0.8644067796610169,
#   'PetalWidthCm': 1.0,
#   'Species': 'Iris-virginica'},
#  {'Id': 20,
#   'SepalLengthCm': 0.7222222222222222,
#   'SepalWidthCm': 0.4583333333333333,
#   'PetalLengthCm': 0.6610169491525424,
#   'PetalWidthCm': 0.5833333333333334,
#   'Species': 'Iris-versicolor'},
#  {'Id': 21,
#   'SepalLengthCm': 0.41666666666666663,
#   'SepalWidthCm': 0.2916666666666667,
#   'PetalLengthCm': 0.6949152542372881,
#   'PetalWidthCm': 0.75,
#   'Species': 'Iris-virginica'},
#  {'Id': 22,
#   'SepalLengthCm': 0.1666666666666668,
#   'SepalWidthCm': 0.1666666666666666,
#   'PetalLengthCm': 0.38983050847457623,
#   'PetalWidthCm': 0.375,
#   'Species': 'Iris-versicolor'},
#  {'Id': 23,
#   'SepalLengthCm': 0.44444444444444453,
#   'SepalWidthCm': 0.41666666666666663,
#   'PetalLengthCm': 0.5423728813559322,
#   'PetalWidthCm': 0.5833333333333334,
#   'Species': 'Iris-versicolor'},
#  {'Id': 24,
#   'SepalLengthCm': 0.5833333333333334,
#   'SepalWidthCm': 0.3749999999999999,
#   'PetalLengthCm': 0.559322033898305,
#   'PetalWidthCm': 0.5,
#   'Species': 'Iris-versicolor'},
#  {'Id': 25,
#   'SepalLengthCm': 0.6944444444444443,
#   'SepalWidthCm': 0.41666666666666663,
#   'PetalLengthCm': 0.7627118644067796,
#   'PetalWidthCm': 0.8333333333333334,
#   'Species': 'Iris-virginica'},
#  {'Id': 26,
#   'SepalLengthCm': 0.3333333333333333,
#   'SepalWidthCm': 0.1249999999999999,
#   'PetalLengthCm': 0.5084745762711864,
#   'PetalWidthCm': 0.5,
#   'Species': 'Iris-versicolor'},
#  {'Id': 27,
#   'SepalLengthCm': 0.25000000000000006,
#   'SepalWidthCm': 0.8749999999999998,
#   'PetalLengthCm': 0.0847457627118644,
#   'PetalWidthCm': 0.0,
#   'Species': 'Iris-setosa'},
#  {'Id': 28,
#   'SepalLengthCm': 0.08333333333333327,
#   'SepalWidthCm': 0.4583333333333333,
#   'PetalLengthCm': 0.0847457627118644,
#   'PetalWidthCm': 0.04166666666666667,
#   'Species': 'Iris-setosa'},
#  {'Id': 29,
#   'SepalLengthCm': 0.027777777777777922,
#   'SepalWidthCm': 0.3749999999999999,
#   'PetalLengthCm': 0.06779661016949151,
#   'PetalWidthCm': 0.04166666666666667,
#   'Species': 'Iris-setosa'},
#  {'Id': 30,
#   'SepalLengthCm': 0.08333333333333327,
#   'SepalWidthCm': 0.6666666666666666,
#   'PetalLengthCm': 0.0,
#   'PetalWidthCm': 0.04166666666666667,
#   'Species': 'Iris-setosa'},
#  {'Id': 31,
#   'SepalLengthCm': 0.08333333333333327,
#   'SepalWidthCm': 0.5,
#   'PetalLengthCm': 0.06779661016949151,
#   'PetalWidthCm': 0.04166666666666667,
#   'Species': 'Iris-setosa'},
#  {'Id': 32,
#   'SepalLengthCm': 0.19444444444444448,
#   'SepalWidthCm': 0.6666666666666666,
#   'PetalLengthCm': 0.06779661016949151,
#   'PetalWidthCm': 0.04166666666666667,
#   'Species': 'Iris-setosa'},
#  {'Id': 33,
#   'SepalLengthCm': 0.22222222222222213,
#   'SepalWidthCm': 0.5416666666666665,
#   'PetalLengthCm': 0.11864406779661016,
#   'PetalWidthCm': 0.16666666666666669,
#   'Species': 'Iris-setosa'},
#  {'Id': 34,
#   'SepalLengthCm': 0.44444444444444453,
#   'SepalWidthCm': 0.5,
#   'PetalLengthCm': 0.6440677966101694,
#   'PetalWidthCm': 0.7083333333333334,
#   'Species': 'Iris-versicolor'},
#  {'Id': 35,
#   'SepalLengthCm': 0.41666666666666663,
#   'SepalWidthCm': 0.3333333333333332,
#   'PetalLengthCm': 0.6949152542372881,
#   'PetalWidthCm': 0.9583333333333333,
#   'Species': 'Iris-virginica'},
#  {'Id': 36,
#   'SepalLengthCm': 0.6666666666666666,
#   'SepalWidthCm': 0.41666666666666663,
#   'PetalLengthCm': 0.711864406779661,
#   'PetalWidthCm': 0.9166666666666666,
#   'Species': 'Iris-virginica'},
#  {'Id': 37,
#   'SepalLengthCm': 0.8333333333333333,
#   'SepalWidthCm': 0.3749999999999999,
#   'PetalLengthCm': 0.8983050847457626,
#   'PetalWidthCm': 0.7083333333333334,
#   'Species': 'Iris-virginica'},
#  {'Id': 38,
#   'SepalLengthCm': 0.611111111111111,
#   'SepalWidthCm': 0.41666666666666663,
#   'PetalLengthCm': 0.711864406779661,
#   'PetalWidthCm': 0.7916666666666666,
#   'Species': 'Iris-virginica'},
#  {'Id': 40,
#   'SepalLengthCm': 0.5833333333333334,
#   'SepalWidthCm': 0.5,
#   'PetalLengthCm': 0.5932203389830508,
#   'PetalWidthCm': 0.5833333333333334,
#   'Species': 'Iris-versicolor'},
#  {'Id': 41,
#   'SepalLengthCm': 0.38888888888888895,
#   'SepalWidthCm': 0.3749999999999999,
#   'PetalLengthCm': 0.5423728813559322,
#   'PetalWidthCm': 0.5,
#   'Species': 'Iris-versicolor'},
#  {'Id': 42,
#   'SepalLengthCm': 0.9166666666666665,
#   'SepalWidthCm': 0.41666666666666663,
#   'PetalLengthCm': 0.9491525423728813,
#   'PetalWidthCm': 0.8333333333333334,
#   'Species': 'Iris-virginica'},
#  {'Id': 43,
#   'SepalLengthCm': 0.19444444444444448,
#   'SepalWidthCm': 0.6249999999999999,
#   'PetalLengthCm': 0.1016949152542373,
#   'PetalWidthCm': 0.20833333333333334,
#   'Species': 'Iris-setosa'},
#  {'Id': 44,
#   'SepalLengthCm': 0.1666666666666668,
#   'SepalWidthCm': 0.4583333333333333,
#   'PetalLengthCm': 0.0847457627118644,
#   'PetalWidthCm': 0.0,
#   'Species': 'Iris-setosa'},
#  {'Id': 45,
#   'SepalLengthCm': 0.30555555555555564,
#   'SepalWidthCm': 0.5833333333333333,
#   'PetalLengthCm': 0.11864406779661016,
#   'PetalWidthCm': 0.04166666666666667,
#   'Species': 'Iris-setosa'},
#  {'Id': 46,
#   'SepalLengthCm': 0.08333333333333327,
#   'SepalWidthCm': 0.5833333333333333,
#   'PetalLengthCm': 0.06779661016949151,
#   'PetalWidthCm': 0.08333333333333333,
#   'Species': 'Iris-setosa'},
#  {'Id': 47,
#   'SepalLengthCm': 0.30555555555555564,
#   'SepalWidthCm': 0.7916666666666665,
#   'PetalLengthCm': 0.11864406779661016,
#   'PetalWidthCm': 0.12500000000000003,
#   'Species': 'Iris-setosa'},
#  {'Id': 48,
#   'SepalLengthCm': 0.4999999999999999,
#   'SepalWidthCm': 0.3333333333333332,
#   'PetalLengthCm': 0.5084745762711864,
#   'PetalWidthCm': 0.5,
#   'Species': 'Iris-versicolor'},
#  {'Id': 49,
#   'SepalLengthCm': 0.4722222222222222,
#   'SepalWidthCm': 0.41666666666666663,
#   'PetalLengthCm': 0.6440677966101694,
#   'PetalWidthCm': 0.7083333333333334,
#   'Species': 'Iris-virginica'},
#  {'Id': 50,
#   'SepalLengthCm': 0.13888888888888887,
#   'SepalWidthCm': 0.41666666666666663,
#   'PetalLengthCm': 0.06779661016949151,
#   'PetalWidthCm': 0.0,
#   'Species': 'Iris-setosa'},
#  {'Id': 51,
#   'SepalLengthCm': 0.5555555555555555,
#   'SepalWidthCm': 0.20833333333333331,
#   'PetalLengthCm': 0.6779661016949152,
#   'PetalWidthCm': 0.75,
#   'Species': 'Iris-virginica'},
#  {'Id': 52,
#   'SepalLengthCm': 0.361111111111111,
#   'SepalWidthCm': 0.3333333333333332,
#   'PetalLengthCm': 0.6610169491525424,
#   'PetalWidthCm': 0.7916666666666666,
#   'Species': 'Iris-virginica'},
#  {'Id': 53,
#   'SepalLengthCm': 0.7222222222222222,
#   'SepalWidthCm': 0.5,
#   'PetalLengthCm': 0.7966101694915254,
#   'PetalWidthCm': 0.9166666666666666,
#   'Species': 'Iris-virginica'},
#  {'Id': 55,
#   'SepalLengthCm': 0.6666666666666666,
#   'SepalWidthCm': 0.4583333333333333,
#   'PetalLengthCm': 0.576271186440678,
#   'PetalWidthCm': 0.5416666666666666,
#   'Species': 'Iris-versicolor'},
#  {'Id': 56,
#   'SepalLengthCm': 0.38888888888888895,
#   'SepalWidthCm': 0.41666666666666663,
#   'PetalLengthCm': 0.5423728813559322,
#   'PetalWidthCm': 0.4583333333333333,
#   'Species': 'Iris-versicolor'},
#  {'Id': 57,
#   'SepalLengthCm': 0.6944444444444443,
#   'SepalWidthCm': 0.3333333333333332,
#   'PetalLengthCm': 0.6440677966101694,
#   'PetalWidthCm': 0.5416666666666666,
#   'Species': 'Iris-versicolor'},
#  {'Id': 58,
#   'SepalLengthCm': 1.0,
#   'SepalWidthCm': 0.7499999999999998,
#   'PetalLengthCm': 0.9152542372881356,
#   'PetalWidthCm': 0.7916666666666666,
#   'Species': 'Iris-virginica'},
#  {'Id': 59,
#   'SepalLengthCm': 0.5555555555555555,
#   'SepalWidthCm': 0.2916666666666667,
#   'PetalLengthCm': 0.6610169491525424,
#   'PetalWidthCm': 0.7083333333333334,
#   'Species': 'Iris-virginica'},
#  {'Id': 60,
#   'SepalLengthCm': 0.361111111111111,
#   'SepalWidthCm': 0.20833333333333331,
#   'PetalLengthCm': 0.4915254237288135,
#   'PetalWidthCm': 0.4166666666666667,
#   'Species': 'Iris-versicolor'},
#  {'Id': 61,
#   'SepalLengthCm': 0.22222222222222213,
#   'SepalWidthCm': 0.6249999999999999,
#   'PetalLengthCm': 0.06779661016949151,
#   'PetalWidthCm': 0.08333333333333333,
#   'Species': 'Iris-setosa'},
#  {'Id': 62,
#   'SepalLengthCm': 0.41666666666666663,
#   'SepalWidthCm': 0.8333333333333333,
#   'PetalLengthCm': 0.033898305084745756,
#   'PetalWidthCm': 0.04166666666666667,
#   'Species': 'Iris-setosa'},
#  {'Id': 63,
#   'SepalLengthCm': 0.5833333333333334,
#   'SepalWidthCm': 0.5,
#   'PetalLengthCm': 0.7288135593220338,
#   'PetalWidthCm': 0.9166666666666666,
#   'Species': 'Iris-virginica'},
#  {'Id': 64,
#   'SepalLengthCm': 0.27777777777777773,
#   'SepalWidthCm': 0.7083333333333333,
#   'PetalLengthCm': 0.0847457627118644,
#   'PetalWidthCm': 0.04166666666666667,
#   'Species': 'Iris-setosa'},
#  {'Id': 65,
#   'SepalLengthCm': 0.4722222222222222,
#   'SepalWidthCm': 0.0833333333333334,
#   'PetalLengthCm': 0.6779661016949152,
#   'PetalWidthCm': 0.5833333333333334,
#   'Species': 'Iris-virginica'},
#  {'Id': 66,
#   'SepalLengthCm': 0.30555555555555564,
#   'SepalWidthCm': 0.5833333333333333,
#   'PetalLengthCm': 0.0847457627118644,
#   'PetalWidthCm': 0.12500000000000003,
#   'Species': 'Iris-setosa'},
#  {'Id': 67,
#   'SepalLengthCm': 0.5277777777777778,
#   'SepalWidthCm': 0.5833333333333333,
#   'PetalLengthCm': 0.7457627118644068,
#   'PetalWidthCm': 0.9166666666666666,
#   'Species': 'Iris-virginica'},
#  {'Id': 68,
#   'SepalLengthCm': 0.1666666666666668,
#   'SepalWidthCm': 0.41666666666666663,
#   'PetalLengthCm': 0.06779661016949151,
#   'PetalWidthCm': 0.04166666666666667,
#   'Species': 'Iris-setosa'},
#  {'Id': 69,
#   'SepalLengthCm': 0.30555555555555564,
#   'SepalWidthCm': 0.41666666666666663,
#   'PetalLengthCm': 0.5932203389830508,
#   'PetalWidthCm': 0.5833333333333334,
#   'Species': 'Iris-versicolor'},
#  {'Id': 70,
#   'SepalLengthCm': 0.13888888888888887,
#   'SepalWidthCm': 0.41666666666666663,
#   'PetalLengthCm': 0.06779661016949151,
#   'PetalWidthCm': 0.08333333333333333,
#   'Species': 'Iris-setosa'},
#  {'Id': 71,
#   'SepalLengthCm': 0.5555555555555555,
#   'SepalWidthCm': 0.3333333333333332,
#   'PetalLengthCm': 0.6949152542372881,
#   'PetalWidthCm': 0.5833333333333334,
#   'Species': 'Iris-virginica'},
#  {'Id': 72,
#   'SepalLengthCm': 0.5833333333333334,
#   'SepalWidthCm': 0.4583333333333333,
#   'PetalLengthCm': 0.7627118644067796,
#   'PetalWidthCm': 0.7083333333333334,
#   'Species': 'Iris-virginica'},
#  {'Id': 73,
#   'SepalLengthCm': 0.4999999999999999,
#   'SepalWidthCm': 0.3333333333333332,
#   'PetalLengthCm': 0.6271186440677966,
#   'PetalWidthCm': 0.4583333333333333,
#   'Species': 'Iris-versicolor'},
#  {'Id': 74,
#   'SepalLengthCm': 0.22222222222222213,
#   'SepalWidthCm': 0.7083333333333333,
#   'PetalLengthCm': 0.0847457627118644,
#   'PetalWidthCm': 0.12500000000000003,
#   'Species': 'Iris-setosa'},
#  {'Id': 75,
#   'SepalLengthCm': 0.611111111111111,
#   'SepalWidthCm': 0.5,
#   'PetalLengthCm': 0.6949152542372881,
#   'PetalWidthCm': 0.7916666666666666,
#   'Species': 'Iris-virginica'},
#  {'Id': 76,
#   'SepalLengthCm': 0.1666666666666668,
#   'SepalWidthCm': 0.4583333333333333,
#   'PetalLengthCm': 0.0847457627118644,
#   'PetalWidthCm': 0.0,
#   'Species': 'Iris-setosa'},
#  {'Id': 77,
#   'SepalLengthCm': 0.611111111111111,
#   'SepalWidthCm': 0.41666666666666663,
#   'PetalLengthCm': 0.8135593220338982,
#   'PetalWidthCm': 0.8750000000000001,
#   'Species': 'Iris-virginica'},
#  {'Id': 78,
#   'SepalLengthCm': 0.6944444444444443,
#   'SepalWidthCm': 0.5,
#   'PetalLengthCm': 0.8305084745762712,
#   'PetalWidthCm': 0.9166666666666666,
#   'Species': 'Iris-virginica'},
#  {'Id': 79,
#   'SepalLengthCm': 0.1666666666666668,
#   'SepalWidthCm': 0.20833333333333331,
#   'PetalLengthCm': 0.5932203389830508,
#   'PetalWidthCm': 0.6666666666666666,
#   'Species': 'Iris-virginica'},
#  {'Id': 80,
#   'SepalLengthCm': 0.11111111111111119,
#   'SepalWidthCm': 0.5,
#   'PetalLengthCm': 0.05084745762711865,
#   'PetalWidthCm': 0.04166666666666667,
#   'Species': 'Iris-setosa'},
#  {'Id': 81,
#   'SepalLengthCm': 0.361111111111111,
#   'SepalWidthCm': 0.41666666666666663,
#   'PetalLengthCm': 0.5254237288135593,
#   'PetalWidthCm': 0.5,
#   'Species': 'Iris-versicolor'},
#  {'Id': 82,
#   'SepalLengthCm': 0.22222222222222213,
#   'SepalWidthCm': 0.5833333333333333,
#   'PetalLengthCm': 0.0847457627118644,
#   'PetalWidthCm': 0.04166666666666667,
#   'Species': 'Iris-setosa'},
#  {'Id': 83,
#   'SepalLengthCm': 0.5833333333333334,
#   'SepalWidthCm': 0.3333333333333332,
#   'PetalLengthCm': 0.7796610169491525,
#   'PetalWidthCm': 0.8750000000000001,
#   'Species': 'Iris-virginica'},
#  {'Id': 84,
#   'SepalLengthCm': 0.9444444444444444,
#   'SepalWidthCm': 0.7499999999999998,
#   'PetalLengthCm': 0.9661016949152542,
#   'PetalWidthCm': 0.8750000000000001,
#   'Species': 'Iris-virginica'},
#  {'Id': 85,
#   'SepalLengthCm': 0.19444444444444448,
#   'SepalWidthCm': 0.5,
#   'PetalLengthCm': 0.033898305084745756,
#   'PetalWidthCm': 0.04166666666666667,
#   'Species': 'Iris-setosa'},
#  {'Id': 86,
#   'SepalLengthCm': 0.8055555555555556,
#   'SepalWidthCm': 0.5,
#   'PetalLengthCm': 0.847457627118644,
#   'PetalWidthCm': 0.7083333333333334,
#   'Species': 'Iris-virginica'},
#  {'Id': 87,
#   'SepalLengthCm': 0.38888888888888895,
#   'SepalWidthCm': 0.7499999999999998,
#   'PetalLengthCm': 0.11864406779661016,
#   'PetalWidthCm': 0.08333333333333333,
#   'Species': 'Iris-setosa'},
#  {'Id': 88,
#   'SepalLengthCm': 0.25000000000000006,
#   'SepalWidthCm': 0.6249999999999999,
#   'PetalLengthCm': 0.0847457627118644,
#   'PetalWidthCm': 0.04166666666666667,
#   'Species': 'Iris-setosa'},
#  {'Id': 89,
#   'SepalLengthCm': 0.4999999999999999,
#   'SepalWidthCm': 0.25,
#   'PetalLengthCm': 0.7796610169491525,
#   'PetalWidthCm': 0.5416666666666666,
#   'Species': 'Iris-virginica'},
#  {'Id': 90,
#   'SepalLengthCm': 0.3333333333333333,
#   'SepalWidthCm': 0.20833333333333331,
#   'PetalLengthCm': 0.5084745762711864,
#   'PetalWidthCm': 0.5,
#   'Species': 'Iris-versicolor'},
#  {'Id': 91,
#   'SepalLengthCm': 0.3333333333333333,
#   'SepalWidthCm': 0.6249999999999999,
#   'PetalLengthCm': 0.05084745762711865,
#   'PetalWidthCm': 0.04166666666666667,
#   'Species': 'Iris-setosa'},
#  {'Id': 92,
#   'SepalLengthCm': 0.6666666666666666,
#   'SepalWidthCm': 0.4583333333333333,
#   'PetalLengthCm': 0.6271186440677966,
#   'PetalWidthCm': 0.5833333333333334,
#   'Species': 'Iris-versicolor'},
#  {'Id': 93,
#   'SepalLengthCm': 0.6388888888888887,
#   'SepalWidthCm': 0.3749999999999999,
#   'PetalLengthCm': 0.6101694915254237,
#   'PetalWidthCm': 0.5,
#   'Species': 'Iris-versicolor'},
#  {'Id': 94,
#   'SepalLengthCm': 0.6666666666666666,
#   'SepalWidthCm': 0.5416666666666665,
#   'PetalLengthCm': 0.7966101694915254,
#   'PetalWidthCm': 0.8333333333333334,
#   'Species': 'Iris-virginica'},
#  {'Id': 95,
#   'SepalLengthCm': 0.5555555555555555,
#   'SepalWidthCm': 0.5833333333333333,
#   'PetalLengthCm': 0.7796610169491525,
#   'PetalWidthCm': 0.9583333333333333,
#   'Species': 'Iris-virginica'},
#  {'Id': 97,
#   'SepalLengthCm': 0.22222222222222213,
#   'SepalWidthCm': 0.7499999999999998,
#   'PetalLengthCm': 0.1016949152542373,
#   'PetalWidthCm': 0.04166666666666667,
#   'Species': 'Iris-setosa'},
#  {'Id': 98,
#   'SepalLengthCm': 0.7222222222222222,
#   'SepalWidthCm': 0.4583333333333333,
#   'PetalLengthCm': 0.6949152542372881,
#   'PetalWidthCm': 0.9166666666666666,
#   'Species': 'Iris-virginica'},
#  {'Id': 99,
#   'SepalLengthCm': 0.19444444444444448,
#   'SepalWidthCm': 0.5416666666666665,
#   'PetalLengthCm': 0.06779661016949151,
#   'PetalWidthCm': 0.04166666666666667,
#   'Species': 'Iris-setosa'},
#  {'Id': 100,
#   'SepalLengthCm': 0.0,
#   'SepalWidthCm': 0.41666666666666663,
#   'PetalLengthCm': 0.016949152542372895,
#   'PetalWidthCm': 0.0,
#   'Species': 'Iris-setosa'},
#  {'Id': 101,
#   'SepalLengthCm': 0.7777777777777776,
#   'SepalWidthCm': 0.41666666666666663,
#   'PetalLengthCm': 0.8305084745762712,
#   'PetalWidthCm': 0.8333333333333334,
#   'Species': 'Iris-virginica'},
#  {'Id': 102,
#   'SepalLengthCm': 0.3333333333333333,
#   'SepalWidthCm': 0.1666666666666666,
#   'PetalLengthCm': 0.4576271186440678,
#   'PetalWidthCm': 0.375,
#   'Species': 'Iris-versicolor'},
#  {'Id': 103,
#   'SepalLengthCm': 0.38888888888888895,
#   'SepalWidthCm': 0.20833333333333331,
#   'PetalLengthCm': 0.6779661016949152,
#   'PetalWidthCm': 0.7916666666666666,
#   'Species': 'Iris-virginica'},
#  {'Id': 104,
#   'SepalLengthCm': 0.361111111111111,
#   'SepalWidthCm': 0.3749999999999999,
#   'PetalLengthCm': 0.4406779661016949,
#   'PetalWidthCm': 0.5,
#   'Species': 'Iris-versicolor'},
#  {'Id': 105,
#   'SepalLengthCm': 0.22222222222222213,
#   'SepalWidthCm': 0.7499999999999998,
#   'PetalLengthCm': 0.15254237288135591,
#   'PetalWidthCm': 0.12500000000000003,
#   'Species': 'Iris-setosa'},
#  {'Id': 106,
#   'SepalLengthCm': 0.13888888888888887,
#   'SepalWidthCm': 0.5833333333333333,
#   'PetalLengthCm': 0.15254237288135591,
#   'PetalWidthCm': 0.04166666666666667,
#   'Species': 'Iris-setosa'},
#  {'Id': 107,
#   'SepalLengthCm': 0.5833333333333334,
#   'SepalWidthCm': 0.3333333333333332,
#   'PetalLengthCm': 0.7796610169491525,
#   'PetalWidthCm': 0.8333333333333334,
#   'Species': 'Iris-virginica'},
#  {'Id': 108,
#   'SepalLengthCm': 0.5833333333333334,
#   'SepalWidthCm': 0.2916666666666667,
#   'PetalLengthCm': 0.7288135593220338,
#   'PetalWidthCm': 0.75,
#   'Species': 'Iris-virginica'},
#  {'Id': 109,
#   'SepalLengthCm': 0.1666666666666668,
#   'SepalWidthCm': 0.4583333333333333,
#   'PetalLengthCm': 0.0847457627118644,
#   'PetalWidthCm': 0.0,
#   'Species': 'Iris-setosa'},
#  {'Id': 110,
#   'SepalLengthCm': 0.44444444444444453,
#   'SepalWidthCm': 0.41666666666666663,
#   'PetalLengthCm': 0.6949152542372881,
#   'PetalWidthCm': 0.7083333333333334,
#   'Species': 'Iris-virginica'},
#  {'Id': 111,
#   'SepalLengthCm': 0.361111111111111,
#   'SepalWidthCm': 0.2916666666666667,
#   'PetalLengthCm': 0.5423728813559322,
#   'PetalWidthCm': 0.5,
#   'Species': 'Iris-versicolor'},
#  {'Id': 112,
#   'SepalLengthCm': 0.41666666666666663,
#   'SepalWidthCm': 0.2916666666666667,
#   'PetalLengthCm': 0.4915254237288135,
#   'PetalWidthCm': 0.4583333333333333,
#   'Species': 'Iris-versicolor'},
#  {'Id': 113,
#   'SepalLengthCm': 0.3333333333333333,
#   'SepalWidthCm': 0.1666666666666666,
#   'PetalLengthCm': 0.47457627118644063,
#   'PetalWidthCm': 0.4166666666666667,
#   'Species': 'Iris-versicolor'},
#  {'Id': 114,
#   'SepalLengthCm': 0.19444444444444448,
#   'SepalWidthCm': 0.0,
#   'PetalLengthCm': 0.423728813559322,
#   'PetalWidthCm': 0.375,
#   'Species': 'Iris-versicolor'},
#  {'Id': 115,
#   'SepalLengthCm': 0.3333333333333333,
#   'SepalWidthCm': 0.9166666666666666,
#   'PetalLengthCm': 0.06779661016949151,
#   'PetalWidthCm': 0.04166666666666667,
#   'Species': 'Iris-setosa'},
#  {'Id': 116,
#   'SepalLengthCm': 0.41666666666666663,
#   'SepalWidthCm': 0.2916666666666667,
#   'PetalLengthCm': 0.6949152542372881,
#   'PetalWidthCm': 0.75,
#   'Species': 'Iris-virginica'},
#  {'Id': 117,
#   'SepalLengthCm': 0.19444444444444448,
#   'SepalWidthCm': 0.5833333333333333,
#   'PetalLengthCm': 0.0847457627118644,
#   'PetalWidthCm': 0.04166666666666667,
#   'Species': 'Iris-setosa'},
#  {'Id': 118,
#   'SepalLengthCm': 0.22222222222222213,
#   'SepalWidthCm': 0.20833333333333331,
#   'PetalLengthCm': 0.3389830508474576,
#   'PetalWidthCm': 0.4166666666666667,
#   'Species': 'Iris-versicolor'},
#  {'Id': 119,
#   'SepalLengthCm': 0.4722222222222222,
#   'SepalWidthCm': 0.0833333333333334,
#   'PetalLengthCm': 0.5084745762711864,
#   'PetalWidthCm': 0.375,
#   'Species': 'Iris-versicolor'},
#  {'Id': 120,
#   'SepalLengthCm': 0.41666666666666663,
#   'SepalWidthCm': 0.25,
#   'PetalLengthCm': 0.5084745762711864,
#   'PetalWidthCm': 0.4583333333333333,
#   'Species': 'Iris-versicolor'},
#  {'Id': 121,
#   'SepalLengthCm': 0.5555555555555555,
#   'SepalWidthCm': 0.20833333333333331,
#   'PetalLengthCm': 0.6610169491525424,
#   'PetalWidthCm': 0.5833333333333334,
#   'Species': 'Iris-versicolor'},
#  {'Id': 122,
#   'SepalLengthCm': 0.30555555555555564,
#   'SepalWidthCm': 0.7083333333333333,
#   'PetalLengthCm': 0.0847457627118644,
#   'PetalWidthCm': 0.04166666666666667,
#   'Species': 'Iris-setosa'},
#  {'Id': 123,
#   'SepalLengthCm': 0.4722222222222222,
#   'SepalWidthCm': 0.2916666666666667,
#   'PetalLengthCm': 0.6949152542372881,
#   'PetalWidthCm': 0.625,
#   'Species': 'Iris-versicolor'},
#  {'Id': 124,
#   'SepalLengthCm': 0.7222222222222222,
#   'SepalWidthCm': 0.4583333333333333,
#   'PetalLengthCm': 0.7457627118644068,
#   'PetalWidthCm': 0.8333333333333334,
#   'Species': 'Iris-virginica'},
#  {'Id': 125,
#   'SepalLengthCm': 0.19444444444444448,
#   'SepalWidthCm': 0.41666666666666663,
#   'PetalLengthCm': 0.1016949152542373,
#   'PetalWidthCm': 0.04166666666666667,
#   'Species': 'Iris-setosa'},
#  {'Id': 126,
#   'SepalLengthCm': 0.38888888888888895,
#   'SepalWidthCm': 0.25,
#   'PetalLengthCm': 0.423728813559322,
#   'PetalWidthCm': 0.375,
#   'Species': 'Iris-versicolor'},
#  {'Id': 127,
#   'SepalLengthCm': 0.4999999999999999,
#   'SepalWidthCm': 0.41666666666666663,
#   'PetalLengthCm': 0.6101694915254237,
#   'PetalWidthCm': 0.5416666666666666,
#   'Species': 'Iris-versicolor'},
#  {'Id': 128,
#   'SepalLengthCm': 0.38888888888888895,
#   'SepalWidthCm': 0.3333333333333332,
#   'PetalLengthCm': 0.5932203389830508,
#   'PetalWidthCm': 0.5,
#   'Species': 'Iris-versicolor'},
#  {'Id': 129,
#   'SepalLengthCm': 0.4722222222222222,
#   'SepalWidthCm': 0.5833333333333333,
#   'PetalLengthCm': 0.5932203389830508,
#   'PetalWidthCm': 0.625,
#   'Species': 'Iris-versicolor'},
#  {'Id': 130,
#   'SepalLengthCm': 0.5555555555555555,
#   'SepalWidthCm': 0.1249999999999999,
#   'PetalLengthCm': 0.576271186440678,
#   'PetalWidthCm': 0.5,
#   'Species': 'Iris-versicolor'},
#  {'Id': 131,
#   'SepalLengthCm': 0.25000000000000006,
#   'SepalWidthCm': 0.5833333333333333,
#   'PetalLengthCm': 0.06779661016949151,
#   'PetalWidthCm': 0.04166666666666667,
#   'Species': 'Iris-setosa'},
#  {'Id': 132,
#   'SepalLengthCm': 0.9444444444444444,
#   'SepalWidthCm': 0.41666666666666663,
#   'PetalLengthCm': 0.8644067796610169,
#   'PetalWidthCm': 0.9166666666666666,
#   'Species': 'Iris-virginica'},
#  {'Id': 133,
#   'SepalLengthCm': 0.611111111111111,
#   'SepalWidthCm': 0.3333333333333332,
#   'PetalLengthCm': 0.6101694915254237,
#   'PetalWidthCm': 0.5833333333333334,
#   'Species': 'Iris-versicolor'},
#  {'Id': 134,
#   'SepalLengthCm': 0.25000000000000006,
#   'SepalWidthCm': 0.2916666666666667,
#   'PetalLengthCm': 0.4915254237288135,
#   'PetalWidthCm': 0.5416666666666666,
#   'Species': 'Iris-versicolor'},
#  {'Id': 135,
#   'SepalLengthCm': 0.6388888888888887,
#   'SepalWidthCm': 0.41666666666666663,
#   'PetalLengthCm': 0.576271186440678,
#   'PetalWidthCm': 0.5416666666666666,
#   'Species': 'Iris-versicolor'},
#  {'Id': 136,
#   'SepalLengthCm': 0.055555555555555594,
#   'SepalWidthCm': 0.1249999999999999,
#   'PetalLengthCm': 0.05084745762711865,
#   'PetalWidthCm': 0.08333333333333333,
#   'Species': 'Iris-setosa'},
#  {'Id': 137,
#   'SepalLengthCm': 0.9444444444444444,
#   'SepalWidthCm': 0.25,
#   'PetalLengthCm': 1.0,
#   'PetalWidthCm': 0.9166666666666666,
#   'Species': 'Iris-virginica'},
#  {'Id': 138,
#   'SepalLengthCm': 0.19444444444444448,
#   'SepalWidthCm': 0.1249999999999999,
#   'PetalLengthCm': 0.38983050847457623,
#   'PetalWidthCm': 0.375,
#   'Species': 'Iris-versicolor'},
#  {'Id': 139,
#   'SepalLengthCm': 0.3333333333333333,
#   'SepalWidthCm': 0.25,
#   'PetalLengthCm': 0.576271186440678,
#   'PetalWidthCm': 0.4583333333333333,
#   'Species': 'Iris-versicolor'},
#  {'Id': 140,
#   'SepalLengthCm': 0.8611111111111112,
#   'SepalWidthCm': 0.3333333333333332,
#   'PetalLengthCm': 0.8644067796610169,
#   'PetalWidthCm': 0.75,
#   'Species': 'Iris-virginica'},
#  {'Id': 141,
#   'SepalLengthCm': 0.11111111111111119,
#   'SepalWidthCm': 0.5,
#   'PetalLengthCm': 0.1016949152542373,
#   'PetalWidthCm': 0.04166666666666667,
#   'Species': 'Iris-setosa'},
#  {'Id': 142,
#   'SepalLengthCm': 0.4999999999999999,
#   'SepalWidthCm': 0.41666666666666663,
#   'PetalLengthCm': 0.6610169491525424,
#   'PetalWidthCm': 0.7083333333333334,
#   'Species': 'Iris-virginica'},
#  {'Id': 143,
#   'SepalLengthCm': 0.30555555555555564,
#   'SepalWidthCm': 0.7916666666666665,
#   'PetalLengthCm': 0.05084745762711865,
#   'PetalWidthCm': 0.12500000000000003,
#   'Species': 'Iris-setosa'},
#  {'Id': 144,
#   'SepalLengthCm': 0.19444444444444448,
#   'SepalWidthCm': 0.5833333333333333,
#   'PetalLengthCm': 0.1016949152542373,
#   'PetalWidthCm': 0.12500000000000003,
#   'Species': 'Iris-setosa'},
#  {'Id': 145,
#   'SepalLengthCm': 0.6666666666666666,
#   'SepalWidthCm': 0.20833333333333331,
#   'PetalLengthCm': 0.8135593220338982,
#   'PetalWidthCm': 0.7083333333333334,
#   'Species': 'Iris-virginica'},
#  {'Id': 146,
#   'SepalLengthCm': 0.38888888888888895,
#   'SepalWidthCm': 1.0,
#   'PetalLengthCm': 0.0847457627118644,
#   'PetalWidthCm': 0.12500000000000003,
#   'Species': 'Iris-setosa'},
#  {'Id': 147,
#   'SepalLengthCm': 0.13888888888888887,
#   'SepalWidthCm': 0.4583333333333333,
#   'PetalLengthCm': 0.1016949152542373,
#   'PetalWidthCm': 0.04166666666666667,
#   'Species': 'Iris-setosa'},
#  {'Id': 148,
#   'SepalLengthCm': 0.38888888888888895,
#   'SepalWidthCm': 0.3333333333333332,
#   'PetalLengthCm': 0.5254237288135593,
#   'PetalWidthCm': 0.5,
#   'Species': 'Iris-versicolor'},
#  {'Id': 149,
#   'SepalLengthCm': 0.9444444444444444,
#   'SepalWidthCm': 0.3333333333333332,
#   'PetalLengthCm': 0.9661016949152542,
#   'PetalWidthCm': 0.7916666666666666,
#   'Species': 'Iris-virginica'},
#  {'Id': 150,
#   'SepalLengthCm': 0.6666666666666666,
#   'SepalWidthCm': 0.4583333333333333,
#   'PetalLengthCm': 0.7796610169491525,
#   'PetalWidthCm': 0.9583333333333333,
#   'Species': 'Iris-virginica'}]

# %%
for known_sample in KNOWN_SAMPLES:
    known_features = [known_sample[feature] for feature in features]  # Dynamic feature extraction
    print(known_features)
    break
# Out:
# [0.5277777777777778, 0.0833333333333334, 0.5932203389830508, 0.5833333333333334]

# %%
labeled = data.dropna(subset=['Species'])  # Labeled data with known species

# %%
len(features)
# Out:
# 4

# %%
# Normalize with MinMaxScaler
scaler = MinMaxScaler()
normalized_data = scaler.fit_transform(labeled)

print(normalized_data)
